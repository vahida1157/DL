# %%
from tensorflow.keras import datasets, layers, models, losses
from tensorflow import random
import matplotlib.pyplot as plt
import numpy as np

fashion_mnist = datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
print(train_labels)
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
print(train_images.shape)
print(test_images.shape)

plt.figure()
plt.imshow(train_images[42])
plt.colorbar()
plt.grid(False)
plt.title(class_names[train_labels[42]])
plt.show()
train_images = train_images / 255.0
test_images = test_images / 255.0
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.subplots_adjust(hspace=.3)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.title(class_names[train_labels[i]])
    plt.show()
X_train = train_images.reshape((train_images.shape[0], 28, 28, 1))
X_test = test_images.reshape((test_images.shape[0], 28, 28, 1))
print(X_train.shape)
random.set_seed(42)

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss=losses.sparse_categorical_crossentropy, metrics=['accuracy'])
model.summary()
model.fit(X_train, train_labels, validation_data=(X_test, test_labels), epochs=20)
test_loss, test_acc = model.evaluate(X_test, test_labels, verbose=2)
print('Accuracy on test set:', test_acc)
predictions = model.predict(X_test)
print(predictions[0])

print('Predicted label for the first test sample: ',
      np.argmax(predictions[0]))


def plot_image_prediction(i, images, predictions, labels, class_names):
    plt.subplot(1, 2, 1)
    plt.imshow(images[i], cmap=plt.cm.binary)
    prediction = np.argmax(predictions[i])
    color = 'blue' if prediction == labels[i] else 'red'
    plt.title(f"{class_names[labels[i]]} (predicted {class_names[prediction]})", color=color)
    plt.subplot(1, 2, 2)
    plt.grid(False)
    plt.xticks(range(10))
    plot = plt.bar(range(10), predictions[i], color="#777777")
    plt.ylim([0, 1])
    plot[prediction].set_color('red')
    plot[labels[i]].set_color('blue')
    plt.show()


plot_image_prediction(0, test_images, predictions, test_labels, class_names)
filters, _ = model.layers[2].get_weights()
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)
n_filters = 16
for i in range(n_filters):
    filter = filters[:, :, :, i]
    plt.subplot(4, 4, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(filter[:, :, 0], cmap='gray')
    plt.show()
# Out:
# [9 0 0 ... 3 0 5]
# (60000, 28, 28)
# (10000, 28, 28)
# (60000, 28, 28, 1)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten_2 (Flatten)         (None, 1152)              0
#
#  dense_4 (Dense)             (None, 64)                73792
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dense_6 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 171,274
# Trainable params: 171,274
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5084 - accuracy: 0.8109 - val_loss: 0.3531 - val_accuracy: 0.8732
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3211 - accuracy: 0.8821 - val_loss: 0.3666 - val_accuracy: 0.8646
# Epoch 3/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2718 - accuracy: 0.8984 - val_loss: 0.3008 - val_accuracy: 0.8926
# Epoch 4/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2390 - accuracy: 0.9112 - val_loss: 0.2920 - val_accuracy: 0.9005
# Epoch 5/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2151 - accuracy: 0.9208 - val_loss: 0.2731 - val_accuracy: 0.9009
# Epoch 6/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1932 - accuracy: 0.9283 - val_loss: 0.2787 - val_accuracy: 0.8989
# Epoch 7/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1747 - accuracy: 0.9334 - val_loss: 0.2692 - val_accuracy: 0.9089
# Epoch 8/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1595 - accuracy: 0.9399 - val_loss: 0.2655 - val_accuracy: 0.9107
# Epoch 9/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1453 - accuracy: 0.9456 - val_loss: 0.2678 - val_accuracy: 0.9121
# Epoch 10/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1327 - accuracy: 0.9501 - val_loss: 0.2901 - val_accuracy: 0.9132
# Epoch 11/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1214 - accuracy: 0.9552 - val_loss: 0.2892 - val_accuracy: 0.9137
# Epoch 12/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1112 - accuracy: 0.9578 - val_loss: 0.3470 - val_accuracy: 0.9086
# Epoch 13/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1017 - accuracy: 0.9615 - val_loss: 0.3420 - val_accuracy: 0.9095
# Epoch 14/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0940 - accuracy: 0.9643 - val_loss: 0.3348 - val_accuracy: 0.9100
# Epoch 15/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0887 - accuracy: 0.9666 - val_loss: 0.3473 - val_accuracy: 0.9106
# Epoch 16/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0825 - accuracy: 0.9687 - val_loss: 0.3612 - val_accuracy: 0.9103
# Epoch 17/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0749 - accuracy: 0.9721 - val_loss: 0.4009 - val_accuracy: 0.9100
# Epoch 18/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0696 - accuracy: 0.9742 - val_loss: 0.4188 - val_accuracy: 0.9105
# Epoch 19/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0689 - accuracy: 0.9743 - val_loss: 0.4078 - val_accuracy: 0.9109
# Epoch 20/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0641 - accuracy: 0.9761 - val_loss: 0.4223 - val_accuracy: 0.9058
# 313/313 - 1s - loss: 0.4223 - accuracy: 0.9058 - 680ms/epoch - 2ms/step
# Accuracy on test set: 0.9057999849319458
# [9.6648899e-18 4.3432885e-15 1.9412089e-15 2.1765051e-17 2.6356531e-16
#  4.1172155e-10 7.0113099e-16 1.0645744e-10 1.7692008e-19 1.0000000e+00]
# Predicted label for the first test sample:  9
